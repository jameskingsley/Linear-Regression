# %% [markdown]
# ###### The Situation

# %% [markdown]
# * Cam has told me about your work. we have a new client has a modelling project they need with you.
# * The client work in the real estate business,and want to understand the key factors affecting rental price in his region.
# * Also,you will also make useful predictions for the price range range in the same city.
# * you will find more information in the dataset later.

# %% [markdown]
# ###### Dataset Glossary (Column-Wise)
# * BHK: Number of Bedrooms, Hall, Kitchen.
# * Rent: Rent of the Houses/Apartments/Flats.
# * Size: Size of the Houses/Apartments/Flats in Square Feet.
# * Floor: Houses/Apartments/Flats situated in which Floor and Total Number of Floors (Example: Ground out of 2, 3 out of 5, etc.)
# * Area Type: Size of the Houses/Apartments/Flats calculated on either Super Area or Carpet Area or Build Area.
# * Area Locality: Locality of the Houses/Apartments/Flats.
# * City: City where the Houses/Apartments/Flats are Located.
# * Furnishing Status: Furnishing Status of the Houses/Apartments/Flats, either it is Furnished or Semi-Furnished or Unfurnished.
# * Tenant Preferred: Type of Tenant Preferred by the Owner or Agent.
# * Bathroom: Number of Bathrooms.
# * Point of Contact: Whom should you contact for more information regarding the Houses/Apartments/Flats.
#
# ###### Aknowledgement
# * This dataset is gotten from Kaggle.
#
# ######  Key Objectives
#
# * Perform EDA on dataset
# * Split your data and choose a validation framework
# * Fit and tune a linear regression model by checking model assumptions and performing feature engineering
# * Interprete linear regression model.

# %%
#importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.api as sm
import scipy.stats as stats

# %%
df = pd.read_csv(r'C:\Users\JAMES TECH\Downloads\House_Rent_Dataset.csv')

# %%
df.head()
# Out:
#     Posted On  BHK   Rent  Size            Floor    Area Type  \
# 0  2022-05-18    2  10000  1100  Ground out of 2   Super Area
# 1  2022-05-13    2  20000   800       1 out of 3   Super Area
# 2  2022-05-16    2  17000  1000       1 out of 3   Super Area
# 3  2022-07-04    2  10000   800       1 out of 2   Super Area
# 4  2022-05-09    2   7500   850       1 out of 2  Carpet Area
#
#               Area Locality     City Furnishing Status  Tenant Preferred  \
# 0                    Bandel  Kolkata       Unfurnished  Bachelors/Family
# 1  Phool Bagan, Kankurgachi  Kolkata    Semi-Furnished  Bachelors/Family
# 2   Salt Lake City Sector 2  Kolkata    Semi-Furnished  Bachelors/Family
# 3               Dumdum Park  Kolkata       Unfurnished  Bachelors/Family
# 4             South Dum Dum  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# 3         1    Contact Owner
# 4         1    Contact Owner

# %%
#make a copy
data = df.copy()

# %% [markdown]
# * shape

# %%
print("Number of rows: ", data.shape[0])
print('')
print('Number of columns:', data.shape[1])
# Out:
# Number of rows:  4746
#
# Number of columns: 12

# %% [markdown]
# * dataset Information

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4746 entries, 0 to 4745
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Posted On          4746 non-null   object
#  1   BHK                4746 non-null   int64
#  2   Rent               4746 non-null   int64
#  3   Size               4746 non-null   int64
#  4   Floor              4746 non-null   object
#  5   Area Type          4746 non-null   object
#  6   Area Locality      4746 non-null   object
#  7   City               4746 non-null   object
#  8   Furnishing Status  4746 non-null   object
#  9   Tenant Preferred   4746 non-null   object
#  10  Bathroom           4746 non-null   int64
#  11  Point of Contact   4746 non-null   object
# dtypes: int64(4), object(8)
# memory usage: 445.1+ KB

# %% [markdown]
# * There no missing values in the dataset

# %% [markdown]
# * columns

# %%
data.columns
# Out:
# Index(['Posted On', 'BHK', 'Rent', 'Size', 'Floor', 'Area Type',
#        'Area Locality', 'City', 'Furnishing Status', 'Tenant Preferred',
#        'Bathroom', 'Point of Contact'],
#       dtype='object')

# %% [markdown]
# * descriptive statistics

# %%
data.describe()
# Out:
#                BHK          Rent         Size     Bathroom
# count  4746.000000  4.746000e+03  4746.000000  4746.000000
# mean      2.083860  3.499345e+04   967.490729     1.965866
# std       0.832256  7.810641e+04   634.202328     0.884532
# min       1.000000  1.200000e+03    10.000000     1.000000
# 25%       2.000000  1.000000e+04   550.000000     1.000000
# 50%       2.000000  1.600000e+04   850.000000     2.000000
# 75%       3.000000  3.300000e+04  1200.000000     2.000000
# max       6.000000  3.500000e+06  8000.000000    10.000000

# %%
data.describe(include = 'object')
# Out:
#          Posted On       Floor   Area Type Area Locality    City  \
# count         4746        4746        4746          4746    4746
# unique          81         480           3          2235       6
# top     2022-07-06  1 out of 2  Super Area   Bandra West  Mumbai
# freq           311         379        2446            37     972
#
#        Furnishing Status  Tenant Preferred Point of Contact
# count               4746              4746             4746
# unique                 3                 3                3
# top       Semi-Furnished  Bachelors/Family    Contact Owner
# freq                2251              3444             3216

# %% [markdown]
# ###### Key Facts;
# * All numerical columns does not have missing values
# * The mean is correct for each respective column(numerical) even though they may be outliers
# ##### For BHK;
# * 25% and 50% of houses has 2 BHK, This may also mean there are more number of houses with 2 BHK eventhough there may be outliers.
# ###### For Bathroom
# * 25% falls within the minimum number of bathroom per a house. This means that 25% of houses has a single bathroom.
# * 50% and 75% of houses has 2 bathrooms also indicating that they may be more number of houses with two bathrooms until proven.

# %% [markdown]
# ###### EDA

# %% [markdown]
# * BHK

# %%
data['BHK'].unique()
# Out:
# array([2, 1, 3, 6, 4, 5], dtype=int64)

# %%
bhk_count = data['BHK'].value_counts().sort_index(ascending = False).to_frame()
bhk_count
# Out:
#      count
# BHK
# 6        8
# 5       19
# 4      189
# 3     1098
# 2     2265
# 1     1167

# %%
#plotting

bhk_count.plot(figsize= (25,8), kind = 'bar', color = 'red')
plt.title('Number of BHK', size = 25)
# Out:
# Text(0.5, 1.0, 'Number of BHK')

# %% [markdown]
# * The above shows that houses with two BHK are more than other houses while houses with six BHK are the least

# %% [markdown]
# * Floors

# %%
# The first twenty highest number of floors

floor_count = data['Floor'].value_counts().sort_values(ascending = False).head(10).to_frame()
floor_count
# Out:
#                  count
# Floor
# 1 out of 2         379
# Ground out of 2    350
# 2 out of 3         312
# 2 out of 4         308
# 1 out of 3         293
# 3 out of 4         239
# Ground out of 3    209
# 1 out of 4         200
# Ground out of 1    195
# 1 out of 1         134

# %%
# Leats 5 floors
floor_least = data['Floor'].value_counts().sort_values(ascending = True).head(5).to_frame()
floor_least
# Out:
#                   count
# Floor
# 9 out of 35           1
# 11 out of 35          1
# 15 out of 29          1
# 15 out of 30          1
# Ground out of 18      1

# %% [markdown]
# ###### Note;
# * 1 out of 2 has the highest floors
# * while 9 out of 35 and so many others has the least floors

# %%
# Plotting the highest floors
floor_count.plot(kind = 'bar', figsize = (20,5), color = 'Green')
plt.title('Highest Number Of Floors', size = 25)
plt.show()

# %% [markdown]
# * Area Type

# %%
area_type_counts = data['Area Type'].value_counts().sort_values(ascending = False).to_frame()
area_type_counts
# Out:
#              count
# Area Type
# Super Area    2446
# Carpet Area   2298
# Built Area       2

# %% [markdown]
# ######  Note:
# * They are more houses in Area type (Super)
# * They are few houses in area type (Built)
# * The Differences in the houses may be due to development or maybe readily availability of social amenities which is not included in this dataset.

# %%
# plotting 
area_type_counts.plot(kind = 'bar', figsize = (15,8), color = 'Blue')
plt.title('Area Type', size = 20)
plt.show()

# %% [markdown]
# * Area Locality

# %%
area_loc_top = data['Area Locality'].value_counts().sort_values(ascending = False).head(20).to_frame()
area_loc_top
# Out:
#                              count
# Area Locality
# Bandra West                     37
# Gachibowli                      29
# Electronic City                 24
# Velachery                       22
# Miyapur, NH 9                   22
# Madipakkam                      20
# Chembur                         19
# Laxmi Nagar                     19
# K R Puram                       19
# Kondapur                        18
# Iyyappanthangal                 17
# Medavakkam                      17
# Banjara Hills, NH 9             17
# Salt Lake City Sector 2         16
# Sholinganallur                  16
# Chromepet, GST Road             15
# Andheri West                    15
# Vadapalani                      15
# Salt Lake City Sector 1         14
# Murugeshpalya, Airport Road     14

# %%
#plotting area location

area_loc_top.plot(kind = 'bar', color = 'yellow',figsize = (20,8))
plt.title('Area Locality', size = 25)
plt.show()

# %% [markdown]
# * Base on Area Locality, the locality with the highest houses is Bandra West

# %% [markdown]
# * City

# %%
city_counts = data['City'].value_counts().sort_values(ascending = False).to_frame()
city_counts
# Out:
#            count
# City
# Mumbai       972
# Chennai      891
# Bangalore    886
# Hyderabad    868
# Delhi        605
# Kolkata      524

# %%
city_counts.plot(kind = 'bar', color = 'black', figsize = (15,8))
plt.title('City Count', size = 25)
plt.show()

# %% [markdown]
# * Base on City, they ae more houses in Mumbai than every other Cities, while they ae lesser number of houses in Kolkata.

# %% [markdown]
# * Furnishing Status

# %%
data['Furnishing Status'].unique()
# Out:
# array(['Unfurnished', 'Semi-Furnished', 'Furnished'], dtype=object)

# %%
furn_counts = data['Furnishing Status'].value_counts().sort_values().to_frame()
furn_counts
# Out:
#                    count
# Furnishing Status
# Furnished            680
# Unfurnished         1815
# Semi-Furnished      2251

# %%
furn_counts = df['Furnishing Status'].value_counts()
plt.figure(figsize=(6,6))
plt.pie(furn_counts.values, labels=furn_counts.index, autopct='%1.1f%%', startangle=90, colors=['#ff9999','#66b3ff','blue','green'])
plt.title('Distribution of Furnishing Status')
plt.axis('equal')  
plt.show()

# %% [markdown]
# * They are more semi-furnished houses in the dataset than furnished and unfurnished houses

# %% [markdown]
# * Tenant Preferred

# %%
data['Tenant Preferred'].unique()
# Out:
# array(['Bachelors/Family', 'Bachelors', 'Family'], dtype=object)

# %%
ten_counts = data['Tenant Preferred'].value_counts().to_frame()
ten_counts
# Out:
#                   count
# Tenant Preferred
# Bachelors/Family   3444
# Bachelors           830
# Family              472

# %%
ten_counts = df['Tenant Preferred'].value_counts()
plt.figure(figsize=(6,6))
plt.pie(ten_counts.values, labels=ten_counts.index, autopct='%1.1f%%', startangle=90, colors=['#ff9999','#66b3ff','blue','green'])
plt.title('Distribution of Furnishing Status')
plt.axis('equal')  
plt.show()

# %% [markdown]
# * Base on Preferred tenants, There are more number of Bachelors/family than every other.

# %% [markdown]
# * Bathroom

# %%
data['Bathroom'].unique()
# Out:
# array([ 2,  1,  3,  5,  4,  6,  7, 10], dtype=int64)

# %%
bathroom_counts = data['Bathroom'].value_counts().sort_values(ascending = False).to_frame()
bathroom_counts
# Out:
#           count
# Bathroom
# 2          2291
# 1          1474
# 3           749
# 4           156
# 5            60
# 6            12
# 7             3
# 10            1

# %%
#  plotting the bathroom

bathroom_counts.plot(kind = 'bar', color = 'green', figsize = (20,8))
plt.title('Bathroom Counts', size = 25)
plt.show()

# %% [markdown]
# * Houses with two bathrooms are more than others

# %% [markdown]
# * Point of contact

# %%
data['Point of Contact'].unique()
# Out:
# array(['Contact Owner', 'Contact Agent', 'Contact Builder'], dtype=object)

# %%
point_c = data['Point of Contact'].value_counts().to_frame()
point_c
# Out:
#                   count
# Point of Contact
# Contact Owner      3216
# Contact Agent      1529
# Contact Builder       1

# %% [markdown]
# * Contact owners has the highest number of houses
# * Contact agents has the second highest number of houses
# * While the contact builder has just one

# %%
#  plotting the bathroom

point_c.plot(kind = 'bar', color = 'green', figsize = (20,8))
plt.title('point Of sale Counts', size = 25)
plt.show()

# %% [markdown]
# * Posted On

# %%
data['Posted On'].nunique()
# Out:
# 81

# %%
posted_on_counts = data['Posted On'].value_counts().sort_values(ascending = False).head(10).to_frame()
posted_on_counts
# Out:
#             count
# Posted On
# 2022-07-06    311
# 2022-05-12    149
# 2022-06-04    135
# 2022-07-09    126
# 2022-05-23    125
# 2022-05-27    125
# 2022-04-29    114
# 2022-07-07    112
# 2022-06-20    111
# 2022-07-04    110

# %%
posted_on_counts.plot(kind = 'bar', figsize = (20,8), color = 'blue')
plt.title('Top Dates with the Highest Posts')
plt.show()

# %% [markdown]
# * The analysis of the posted on shows the highest number of houses posted in a particular date.
# * The analysis above shows the date with the highest number of houses.

# %% [markdown]
# ###### Relationship between Columns and Price

# %% [markdown]
# * BHK And RENT

# %%
bhk_Rent_top = data.groupby('BHK')['Rent'].max().sort_values(ascending = False).head(5).to_frame()
bhk_Rent_top
# Out:
#         Rent
# BHK
# 3    3500000
# 4    1200000
# 5     650000
# 2     600000
# 6     280000

# %% [markdown]
# * Bathroom And Rent

# %%
bath_Rent_top = data.groupby('Bathroom')['Rent'].max().sort_values(ascending = False).head(10).to_frame()
bath_Rent_top
# Out:
#              Rent
# Bathroom
# 3         3500000
# 4         1200000
# 5          680000
# 2          600000
# 6          400000
# 10         200000
# 7          150000
# 1          100000

# %% [markdown]
# Size and rent

# %%
size_Rent_top = data.groupby('Size')['Rent'].max().sort_values(ascending = False).head(10).to_frame()
size_Rent_top
# Out:
#          Rent
# Size
# 2500  3500000
# 5000  1200000
# 3064  1000000
# 3200   850000
# 1962   680000
# 3000   650000
# 950    600000
# 4500   600000
# 4000   530000
# 3900   500000

# %% [markdown]
# * Area Type and Rent

# %%
Area_Rent_top = data.groupby('Area Type')['Rent'].max().sort_values(ascending = False).head(10).to_frame()
Area_Rent_top
# Out:
#                 Rent
# Area Type
# Carpet Area  3500000
# Super Area    350000
# Built Area     15000

# %% [markdown]
# * Area Locality

# %%
Area_Locality_Rent_top = data.groupby('Area Locality')['Rent'].max().sort_values(ascending = False).head(10).to_frame()
Area_Locality_Rent_top
# Out:
#                              Rent
# Area Locality
# Marathahalli              3500000
# Juhu                      1200000
# Raheja Artesia, Worli     1000000
# Breach Candy               850000
# Lady Ratan Tower, Worli    700000
# Khar West                  680000
# Mount Marry, Bandra West   600000
# Bandra West                600000
# Vettuvankeni               600000
# Bandra East                600000

# %% [markdown]
# * City And Rent

# %%
city_Rent_top = data.groupby('City')['Rent'].max().sort_values(ascending = False).to_frame()
city_Rent_top
# Out:
#               Rent
# City
# Bangalore  3500000
# Mumbai     1200000
# Chennai     600000
# Delhi       530000
# Hyderabad   400000
# Kolkata     180000

# %% [markdown]
# * Furnishing Status and Rent

# %%
furn_Rent_top = data.groupby('Furnishing Status')['Rent'].max().sort_values(ascending = False).head(10).to_frame()
furn_Rent_top
# Out:
#                       Rent
# Furnishing Status
# Semi-Furnished     3500000
# Furnished           850000
# Unfurnished         600000

# %% [markdown]
# * Tenant preferred

# %%
tent_Rent_top = data.groupby('Tenant Preferred')['Rent'].max().sort_values(ascending = False).head(10).to_frame()
tent_Rent_top
# Out:
#                      Rent
# Tenant Preferred
# Bachelors         3500000
# Bachelors/Family  1200000
# Family            1000000

# %% [markdown]
# * Point of Contact

# %%
point_Rent_top = data.groupby('Point of Contact')['Rent'].max().sort_values(ascending = False).to_frame()
point_Rent_top
# Out:
#                      Rent
# Point of Contact
# Contact Agent     3500000
# Contact Owner      600000
# Contact Builder      5500

# %% [markdown]
# ######  Regression / Correlational Analysis

# %% [markdown]
# Size And Rent

# %%
po_rent_corr = data[['Size','Rent']].corr()
po_rent_corr
# Out:
#           Size      Rent
# Size  1.000000  0.413551
# Rent  0.413551  1.000000

# %%
sns.regplot(x = 'Rent', y = 'Size', data = data)
# Out:
# <Axes: xlabel='Rent', ylabel='Size'>

# %% [markdown]
# * There is a positive relationship between the Rent and the size. This means that the higher the size of the house, the higher the rent

# %% [markdown]
# * Bathroom And Rent

# %%
sns.regplot(x='Bathroom',y='Rent', data = data)
# Out:
# <Axes: xlabel='Bathroom', ylabel='Rent'>

# %%
bath_cor = data[['Bathroom','Rent']].corr()
bath_cor
# Out:
#           Bathroom      Rent
# Bathroom  1.000000  0.441215
# Rent      0.441215  1.000000

# %% [markdown]
# * There is a moderate positive relationship between Bathroom and Rent.
# * This means that the higher the number of bathrooms in a house the hiher the rent

# %% [markdown]
# BHK and RENT

# %%
bhk_corr = data[['BHK','Rent']].corr()
bhk_corr
# Out:
#            BHK      Rent
# BHK   1.000000  0.369718
# Rent  0.369718  1.000000

# %%
sns.regplot(x = 'BHK', y = 'Rent', data = data)
# Out:
# <Axes: xlabel='BHK', ylabel='Rent'>

# %% [markdown]
# * There is also a positive moderate relationship between BHK and Rent. This means that the higher the BHK,the higher the Rent

# %% [markdown]
# ###### Correlation summary

# %%
matrix_cor = data.corr(numeric_only = True)
matrix_cor
# Out:
#                BHK      Rent      Size  Bathroom
# BHK       1.000000  0.369718  0.716145  0.794885
# Rent      0.369718  1.000000  0.413551  0.441215
# Size      0.716145  0.413551  1.000000  0.740703
# Bathroom  0.794885  0.441215  0.740703  1.000000

# %%
sns.heatmap(matrix_cor, vmin=-1, vmax = 1, annot = True, cmap = 'coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# * There is no negative relationship amongst the numerical variables.
# * This may also post multicollinearity,but that wil be dealt with during prepocessing

# %% [markdown]
# ###### Using Pair Plots

# %%
sns.pairplot(data, corner = True)
# Out:
# C:\Users\JAMES TECH\Documents\New folder\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# ######  Machine Learning

# %% [markdown]
# ###### Preprocessing

# %%
df_pre = df.copy()

# %%
df_pre.describe(include = 'all')
# Out:
#          Posted On          BHK          Rent         Size       Floor  \
# count         4746  4746.000000  4.746000e+03  4746.000000        4746
# unique          81          NaN           NaN          NaN         480
# top     2022-07-06          NaN           NaN          NaN  1 out of 2
# freq           311          NaN           NaN          NaN         379
# mean           NaN     2.083860  3.499345e+04   967.490729         NaN
# std            NaN     0.832256  7.810641e+04   634.202328         NaN
# min            NaN     1.000000  1.200000e+03    10.000000         NaN
# 25%            NaN     2.000000  1.000000e+04   550.000000         NaN
# 50%            NaN     2.000000  1.600000e+04   850.000000         NaN
# 75%            NaN     3.000000  3.300000e+04  1200.000000         NaN
# max            NaN     6.000000  3.500000e+06  8000.000000         NaN
#
#          Area Type Area Locality    City Furnishing Status  Tenant Preferred  \
# count         4746          4746    4746              4746              4746
# unique           3          2235       6                 3                 3
# top     Super Area   Bandra West  Mumbai    Semi-Furnished  Bachelors/Family
# freq          2446            37     972              2251              3444
# mean           NaN           NaN     NaN               NaN               NaN
# std            NaN           NaN     NaN               NaN               NaN
# min            NaN           NaN     NaN               NaN               NaN
# 25%            NaN           NaN     NaN               NaN               NaN
# 50%            NaN           NaN     NaN               NaN               NaN
# 75%            NaN           NaN     NaN               NaN               NaN
# max            NaN           NaN     NaN               NaN               NaN
#
#            Bathroom Point of Contact
# count   4746.000000             4746
# unique          NaN                3
# top             NaN    Contact Owner
# freq            NaN             3216
# mean       1.965866              NaN
# std        0.884532              NaN
# min        1.000000              NaN
# 25%        1.000000              NaN
# 50%        2.000000              NaN
# 75%        2.000000              NaN
# max       10.000000              NaN

# %% [markdown]
# * posted on has 81 unique values, Floor has 480 unique values while Area Locality has 2235 unique values.
# * This columns with so many unique values will affect our predictions

# %%
#dropping the columns
df_cleaned = df_pre.drop(['Posted On','Floor','Area Locality'], axis = 1, inplace = True)

# %%
df_pre.head()
# Out:
#    BHK   Rent  Size    Area Type     City Furnishing Status  Tenant Preferred  \
# 0    2  10000  1100   Super Area  Kolkata       Unfurnished  Bachelors/Family
# 1    2  20000   800   Super Area  Kolkata    Semi-Furnished  Bachelors/Family
# 2    2  17000  1000   Super Area  Kolkata    Semi-Furnished  Bachelors/Family
# 3    2  10000   800   Super Area  Kolkata       Unfurnished  Bachelors/Family
# 4    2   7500   850  Carpet Area  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact
# 0         2    Contact Owner
# 1         1    Contact Owner
# 2         1    Contact Owner
# 3         1    Contact Owner
# 4         1    Contact Owner

# %% [markdown]
# * Outliers Treatment

# %%
sns.boxenplot(df_pre['BHK'])
# Out:
# <Axes: >

# %% [markdown]
# * No outliers

# %%
sns.boxenplot(df_pre['Rent'])
# Out:
# <Axes: >

# %%
sns.distplot(df_pre['Rent'])
# Out:
# C:\Users\JAMES TECH\AppData\Local\Temp\ipykernel_864\722567172.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_pre['Rent'])
# <Axes: xlabel='Rent', ylabel='Density'>

# %% [markdown]
# * There are outliers in the Rent column

# %%
q = df_pre['Rent'].quantile(0.99)
df_1 =df_pre[df_pre['Rent']<q]

# %%
sns.boxenplot(df_1['Rent'])
# Out:
# <Axes: >

# %%
sns.distplot(df_1['Rent'])
# Out:
# C:\Users\JAMES TECH\AppData\Local\Temp\ipykernel_864\4163610680.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_1['Rent'])
# <Axes: xlabel='Rent', ylabel='Density'>

# %% [markdown]
# * Bathroom

# %%
sns.boxenplot(df_1['Bathroom'])
# Out:
# <Axes: >

# %%
q = df_1['Bathroom'].quantile(0.99)
df_2 =df_1[df_1['Bathroom']<q]

# %% [markdown]
# * Size

# %%
sns.boxenplot(df_2['Size'])
# Out:
# <Axes: >

# %%
q = df_2['Size'].quantile(0.99)
df_3 =df_2[df_2['Size']<q]

# %%
df_process = df_3.copy()

# %%
df_process.describe()
# Out:
#                BHK           Rent         Size     Bathroom
# count  4588.000000    4588.000000  4588.000000  4588.000000
# mean      2.021796   27542.048823   898.542502     1.882084
# std       0.761772   33931.385410   483.100099     0.745776
# min       1.000000    1200.000000    10.000000     1.000000
# 25%       1.000000   10000.000000   550.000000     1.000000
# 50%       2.000000   15000.000000   800.000000     2.000000
# 75%       3.000000   30000.000000  1180.000000     2.000000
# max       6.000000  290000.000000  2780.000000     4.000000

# %% [markdown]
# ######  Assumptions

# %% [markdown]
# * Linearity

# %%
f,(ax1,ax2,ax3) = plt.subplots(1,3, sharey=True, figsize = (15,3))
ax1.scatter(df_process['Size'], df_process['Rent'])
ax1.set_title('Size And Rent ')
ax2.scatter(df_process['BHK'], df_process['Rent'])
ax2.set_title('BHK and Rent')
ax3.scatter(df_process['Bathroom'], df_process['Rent'])
ax3.set_title('Bathroom and Rent')

plt.show()

# %% [markdown]
# * The above is not linear
# * So, we will have to  relax the assumption

# %%
log_Rent = np.log(df_process['Rent'])
df_process['log_Rent'] = log_Rent

# %%
f,(ax1,ax2,ax3) = plt.subplots(1,3, sharey=True, figsize = (15,3))
ax1.scatter(df_process['Size'], df_process['log_Rent'])
ax1.set_title('Size And log_Rent ')
ax2.scatter(df_process['BHK'], df_process['log_Rent'])
ax2.set_title('BHK and log_Rent')
ax3.scatter(df_process['Bathroom'], df_process['log_Rent'])
ax3.set_title('Bathroom and log_Rent')

plt.show()

# %% [markdown]
# * Linearity satisfied

# %%
#drop the rent column
df_process = df_process.drop(columns=['Rent'], axis=1)

# %%
df_process.head()
# Out:
#    BHK  Size    Area Type     City Furnishing Status  Tenant Preferred  \
# 0    2  1100   Super Area  Kolkata       Unfurnished  Bachelors/Family
# 1    2   800   Super Area  Kolkata    Semi-Furnished  Bachelors/Family
# 2    2  1000   Super Area  Kolkata    Semi-Furnished  Bachelors/Family
# 3    2   800   Super Area  Kolkata       Unfurnished  Bachelors/Family
# 4    2   850  Carpet Area  Kolkata       Unfurnished         Bachelors
#
#    Bathroom Point of Contact  log_Rent
# 0         2    Contact Owner  9.210340
# 1         1    Contact Owner  9.903488
# 2         1    Contact Owner  9.740969
# 3         1    Contact Owner  9.210340
# 4         1    Contact Owner  8.922658

# %% [markdown]
# * Multicollinearity

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
variables = df_process[['BHK','Size','Bathroom']]
vif = pd.DataFrame()
vif['VIF'] =[variance_inflation_factor(variables.values, i) for i in range(variables.shape[1])]
vif['Features'] = variables.columns

# %%
vif
# Out:
#          VIF  Features
# 0  19.550393       BHK
# 1   9.829866      Size
# 2  18.752358  Bathroom

# %% [markdown]
# * The BHK and The Bathroom has high multicollinearity and as such should be dropped

# %%
#drop BHK and Bathroom
df_process.drop(['BHK', 'Bathroom'], axis=1, inplace=True)

# %%
df_process.head()
# Out:
#    Size    Area Type     City Furnishing Status  Tenant Preferred  \
# 0  1100   Super Area  Kolkata       Unfurnished  Bachelors/Family
# 1   800   Super Area  Kolkata    Semi-Furnished  Bachelors/Family
# 2  1000   Super Area  Kolkata    Semi-Furnished  Bachelors/Family
# 3   800   Super Area  Kolkata       Unfurnished  Bachelors/Family
# 4   850  Carpet Area  Kolkata       Unfurnished         Bachelors
#
#   Point of Contact  log_Rent
# 0    Contact Owner  9.210340
# 1    Contact Owner  9.903488
# 2    Contact Owner  9.740969
# 3    Contact Owner  9.210340
# 4    Contact Owner  8.922658

# %% [markdown]
# ##### Creating Dummies

# %%
df_dumy = pd.get_dummies(df_process, drop_first = True)*1

# %%
df_dumy.head()
# Out:
#    Size  log_Rent  Area Type_Carpet Area  Area Type_Super Area  City_Chennai  \
# 0  1100  9.210340                      0                     1             0
# 1   800  9.903488                      0                     1             0
# 2  1000  9.740969                      0                     1             0
# 3   800  9.210340                      0                     1             0
# 4   850  8.922658                      1                     0             0
#
#    City_Delhi  City_Hyderabad  City_Kolkata  City_Mumbai  \
# 0           0               0             1            0
# 1           0               0             1            0
# 2           0               0             1            0
# 3           0               0             1            0
# 4           0               0             1            0
#
#    Furnishing Status_Semi-Furnished  Furnishing Status_Unfurnished  \
# 0                                 0                              1
# 1                                 1                              0
# 2                                 1                              0
# 3                                 0                              1
# 4                                 0                              1
#
#    Tenant Preferred_Bachelors/Family  Tenant Preferred_Family  \
# 0                                  1                        0
# 1                                  1                        0
# 2                                  1                        0
# 3                                  1                        0
# 4                                  0                        0
#
#    Point of Contact_Contact Builder  Point of Contact_Contact Owner
# 0                                 0                               1
# 1                                 0                               1
# 2                                 0                               1
# 3                                 0                               1
# 4                                 0                               1

# %%
df_final = df_dumy.copy()

# %% [markdown]
# ######  Standardization

# %%
target = df_final['log_Rent']
features = df_final.drop(['log_Rent'], axis = 1)

# %% [markdown]
# * Using standard scaler

# %%
from sklearn.preprocessing import StandardScaler

# %%
#initialize the scaler
scaler = StandardScaler()
#fit the features
scaler.fit(features)
# Out:
# StandardScaler()

# %%
scaled_features = scaler.transform(features)
scaled_features
# Out:
# array([[ 0.4170553 , -0.9502341 ,  0.95106503, ..., -0.32732684,
#         -0.01476507,  0.66370351],
#        [-0.2040017 , -0.9502341 ,  0.95106503, ..., -0.32732684,
#         -0.01476507,  0.66370351],
#        [ 0.2100363 , -0.9502341 ,  0.95106503, ..., -0.32732684,
#         -0.01476507,  0.66370351],
#        ...,
#        [ 1.7626788 ,  1.05237226, -1.05145281, ..., -0.32732684,
#         -0.01476507, -1.50669686],
#        [ 1.2451313 ,  1.05237226, -1.05145281, ...,  3.05505046,
#         -0.01476507, -1.50669686],
#        [ 0.2100363 ,  1.05237226, -1.05145281, ..., -0.32732684,
#         -0.01476507,  0.66370351]])

# %% [markdown]
# ######  Data Splitting

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(scaled_features, target,test_size = 0.2, random_state=200)

# %% [markdown]
# ######  Creating a regression model

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_hat = model.predict(x_train)

# %%
plt.scatter(y_train, y_hat)
plt.xlabel('target(y_train)',size = 18)
plt.ylabel('predictions(y_hat)',size = 18)
plt.xlim(6,13)
plt.ylim(6,13)
plt.show()

# %% [markdown]
# * The model has past the homoscedacity test

# %% [markdown]
# ###### Test with residuals plotting

# %%
sns.distplot(y_train-y_hat)
plt.title('Residual PDFs', size = 20)
plt.show()
# Out:
# C:\Users\JAMES TECH\AppData\Local\Temp\ipykernel_864\835777048.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(y_train-y_hat)

# %% [markdown]
# * The residual plot is normal
# * But there is a little overesimation at the left side.

# %% [markdown]
# ######  Scorring the model

# %% [markdown]
# R2

# %%
model.score(x_train,y_train)
# Out:
# 0.7523194542338011

# %% [markdown]
# * Weight Bias

# %%
model.intercept_
# Out:
# 9.797623114746528

# %%
model.coef_
# Out:
# array([ 0.427644  ,  0.10961141,  0.06673556,  0.0072755 ,  0.0951936 ,
#        -0.04356814, -0.08062333,  0.436876  , -0.09034699, -0.14117204,
#        -0.01094036, -0.02008964, -0.00787178, -0.16048277])

# %%
# creating a summary table
model_summary = pd.DataFrame(features.columns.values, columns = ['Features'])
model_summary['Weights'] = model.coef_
model_summary
# Out:
#                              Features   Weights
# 0                                Size  0.427644
# 1               Area Type_Carpet Area  0.109611
# 2                Area Type_Super Area  0.066736
# 3                        City_Chennai  0.007276
# 4                          City_Delhi  0.095194
# 5                      City_Hyderabad -0.043568
# 6                        City_Kolkata -0.080623
# 7                         City_Mumbai  0.436876
# 8    Furnishing Status_Semi-Furnished -0.090347
# 9       Furnishing Status_Unfurnished -0.141172
# 10  Tenant Preferred_Bachelors/Family -0.010940
# 11            Tenant Preferred_Family -0.020090
# 12   Point of Contact_Contact Builder -0.007872
# 13     Point of Contact_Contact Owner -0.160483

# %% [markdown]
# * Negative means the target decreases as the feature increases
# * Positive weght means that the target increases as the feature increases

# %% [markdown]
# ######  Testing The model

# %%
y_hat_test = model.predict(x_test)

# %%
plt.scatter(y_test, y_hat_test)
plt.xlabel('target(y_test)',size = 18)
plt.ylabel('predictions(y_hat_test)',size = 18)
plt.xlim(6,13)
plt.ylim(6,13)
plt.show()

# %% [markdown]
# * DataFrame performance

# %%
df_pf = pd.DataFrame(np.exp(y_hat_test), columns = ['Predictions'])
df_pf.head(10)
# Out:
#     Predictions
# 0  13111.699670
# 1  15200.211941
# 2   9428.315126
# 3   7501.978438
# 4   5995.247530
# 5   5383.894025
# 6   8234.708682
# 7   5716.912707
# 8  73552.152848
# 9   9775.053522

# %%
y_test = y_test.reset_index(drop = True)
y_test
# Out:
# 0       9.392662
# 1       9.159047
# 2       9.305651
# 3       8.987197
# 4       8.517193
#          ...
# 913     9.433484
# 914     8.779557
# 915    10.545341
# 916     9.472705
# 917    11.608236
# Name: log_Rent, Length: 918, dtype: float64

# %% [markdown]
# ######  Residuals

# %%
df_pf['Target'] =np.exp(y_test)
df_pf
# Out:
#       Predictions    Target
# 0    13111.699670   12000.0
# 1    15200.211941    9500.0
# 2     9428.315126   11000.0
# 3     7501.978438    8000.0
# 4     5995.247530    5000.0
# ..            ...       ...
# 913  18508.111732   12500.0
# 914   8046.792754    6500.0
# 915  44669.713279   38000.0
# 916  11870.688837   13000.0
# 917  69445.303910  110000.0
#
# [918 rows x 2 columns]

# %%
df_pf['Residual'] = df_pf['Target']-df_pf['Predictions']

# %%
df_pf['Difference%'] =np.absolute(df_pf['Residual']/df_pf['Target']*100)
df_pf
# Out:
#       Predictions    Target      Residual  Difference%
# 0    13111.699670   12000.0  -1111.699670     9.264164
# 1    15200.211941    9500.0  -5700.211941    60.002231
# 2     9428.315126   11000.0   1571.684874    14.288044
# 3     7501.978438    8000.0    498.021562     6.225270
# 4     5995.247530    5000.0   -995.247530    19.904951
# ..            ...       ...           ...          ...
# 913  18508.111732   12500.0  -6008.111732    48.064894
# 914   8046.792754    6500.0  -1546.792754    23.796812
# 915  44669.713279   38000.0  -6669.713279    17.551877
# 916  11870.688837   13000.0   1129.311163     8.687009
# 917  69445.303910  110000.0  40554.696090    36.867906
#
# [918 rows x 4 columns]

# %%
# to display all rows
pd.options.display.max_rows = 999

# to make the dataset more readable
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# sort values by difference in %
df_pf.sort_values(by = ['Difference%'])
# Out:
#      Predictions    Target  Residual  Difference%
# 881     19002.96  19000.00     -2.96         0.02
# 860     13003.38  13000.00     -3.38         0.03
# 438     15012.66  15000.00    -12.66         0.08
# 277      7991.24   8000.00      8.76         0.11
# 149     14973.78  15000.00     26.22         0.17
# 47       7012.27   7000.00    -12.27         0.18
# 587     46888.79  47000.00    111.21         0.24
# 276     39898.51  40000.00    101.49         0.25
# 549     74771.79  75000.00    228.21         0.30
# 546     12543.97  12500.00    -43.97         0.35
# 435     22084.00  22000.00    -84.00         0.38
# 733     15909.38  16000.00     90.62         0.57
# 30      65478.85  65000.00   -478.85         0.74
# 674     46600.53  47000.00    399.47         0.85
# 314     18665.56  18500.00   -165.56         0.89
# 885      9902.17  10000.00     97.83         0.98
# 590     17168.09  17000.00   -168.09         0.99
# 329     28298.20  28000.00   -298.20         1.07
# 653     11858.36  12000.00    141.64         1.18
# 671      7407.94   7500.00     92.06         1.23
# 559     39484.00  40000.00    516.00         1.29
# 216     12830.66  13000.00    169.34         1.30
# 489     20725.18  21000.00    274.82         1.31
# 625      6907.38   7000.00     92.62         1.32
# 813     13686.46  13500.00   -186.46         1.38
# 445     26622.28  27000.00    377.72         1.40
# 382      6897.78   7000.00    102.22         1.46
# 300      8117.95   8000.00   -117.95         1.47
# 541     18265.88  18000.00   -265.88         1.48
# 169     12188.05  12000.00   -188.05         1.57
# 252      9842.52  10000.00    157.48         1.57
# 476      9842.52  10000.00    157.48         1.57
# 785     14750.78  15000.00    249.22         1.66
# 397     19666.21  20000.00    333.79         1.67
# 417     20339.19  20000.00   -339.19         1.70
# 15      26539.89  27000.00    460.11         1.70
# 253     18314.55  18000.00   -314.55         1.75
# 58      16697.07  17000.00    302.93         1.78
# 884     10801.32  11000.00    198.68         1.81
# 296     52035.71  53000.00    964.29         1.82
# 163     63816.03  65000.00   1183.97         1.82
# 383     11765.08  12000.00    234.92         1.96
# 702     15316.00  15000.00   -316.00         2.11
# 206     17614.44  18000.00    385.56         2.14
# 560     78263.65  80000.00   1736.35         2.17
# 108     15329.52  15000.00   -329.52         2.20
# 515     11732.73  12000.00    267.27         2.23
# 336      6841.80   7000.00    158.20         2.26
# 228      7329.64   7500.00    170.36         2.27
# 911     13182.96  13500.00    317.04         2.35
# 201     14634.21  15000.00    365.79         2.44
# 194     12296.43  12000.00   -296.43         2.47
# 882     12297.56  12000.00   -297.56         2.48
# 280     10260.65  10000.00   -260.65         2.61
# 48      12172.57  12500.00    327.43         2.62
# 450      6676.70   6500.00   -176.70         2.72
# 442     14572.63  15000.00    427.37         2.85
# 529     53543.61  52000.00  -1543.61         2.97
# 500     13093.84  13500.00    406.16         3.01
# 56       9272.91   9000.00   -272.91         3.03
# 85       8245.36   8000.00   -245.36         3.07
# 703     40204.69  39000.00  -1204.69         3.09
# 751     33908.32  35000.00   1091.68         3.12
# 466      8255.85   8000.00   -255.85         3.20
# 148     25810.02  25000.00   -810.02         3.24
# 900      7229.18   7000.00   -229.18         3.27
# 174     43498.94  45000.00   1501.06         3.34
# 580     77503.04  75000.00  -2503.04         3.34
# 624     77574.73  75000.00  -2574.73         3.43
# 256      9656.24  10000.00    343.76         3.44
# 887     25859.44  25000.00   -859.44         3.44
# 748     24837.80  24000.00   -837.80         3.49
# 374     22189.62  23000.00    810.38         3.52
# 325     62667.57  65000.00   2332.43         3.59
# 618     12956.06  12500.00   -456.06         3.65
# 429      8188.84   8500.00    311.16         3.66
# 734     31112.43  30000.00  -1112.43         3.71
# 441     43323.70  45000.00   1676.30         3.73
# 726      9855.04   9500.00   -355.04         3.74
# 716     52405.56  54500.00   2094.44         3.84
# 186     23075.12  24000.00    924.88         3.85
# 663     62361.45  65000.00   2638.55         4.06
# 746     15342.62  16000.00    657.38         4.11
# 408      7813.45   7500.00   -313.45         4.18
# 243     11465.54  11000.00   -465.54         4.23
# 780      8618.54   9000.00    381.46         4.24
# 440     12510.63  12000.00   -510.63         4.26
# 273     13384.41  14000.00    615.59         4.40
# 192     14325.42  15000.00    674.58         4.50
# 617     12543.97  12000.00   -543.97         4.53
# 640     19079.78  20000.00    920.22         4.60
# 551     43985.42  42000.00  -1985.42         4.73
# 650     16762.85  16000.00   -762.85         4.77
# 286      9429.18   9000.00   -429.18         4.77
# 686     66531.98  70000.00   3468.02         4.95
# 758     87131.10  83000.00  -4131.10         4.98
# 848     11397.48  12000.00    602.52         5.02
# 61      13655.77  13000.00   -655.77         5.04
# 193      8422.05   8000.00   -422.05         5.28
# 538      8996.93   9500.00    503.07         5.30
# 685      6325.44   6000.00   -325.44         5.42
# 92      54881.94  52000.00  -2881.94         5.54
# 294     13689.64  14500.00    810.36         5.59
# 448      9503.95   9000.00   -503.95         5.60
# 872     15853.68  15000.00   -853.68         5.69
# 308      8984.91   8500.00   -484.91         5.70
# 344      9429.18  10000.00    570.82         5.71
# 80      30171.64  32000.00   1828.36         5.71
# 840      7407.94   7000.00   -407.94         5.83
# 205     23289.58  22000.00  -1289.58         5.86
# 337      8459.99   9000.00    540.01         6.00
# 433     15033.14  16000.00    966.86         6.04
# 279      9391.32  10000.00    608.68         6.09
# 68       6102.74   6500.00    397.26         6.11
# 427     49872.75  47000.00  -2872.75         6.11
# 585      9855.04  10500.00    644.96         6.14
# 762     11254.62  12000.00    745.38         6.21
# 868     37513.93  40000.00   2486.07         6.22
# 3        7501.98   8000.00    498.02         6.23
# 139     28103.50  30000.00   1896.50         6.32
# 378     25520.99  24000.00  -1520.99         6.34
# 894     14042.72  15000.00    957.28         6.38
# 472     18720.98  20000.00   1279.02         6.40
# 898      6387.60   6000.00   -387.60         6.46
# 283      6545.55   7000.00    454.45         6.49
# 642     15979.96  15000.00   -979.96         6.53
# 765     10653.48  10000.00   -653.48         6.53
# 240     93463.46 100000.00   6536.54         6.54
# 389     15980.74  15000.00   -980.74         6.54
# 752     18683.24  20000.00   1316.76         6.58
# 116     46691.44  50000.00   3308.56         6.62
# 362     14005.40  15000.00    994.60         6.63
# 400     23311.64  25000.00   1688.36         6.75
# 363      8370.57   9000.00    629.43         6.99
# 138     15342.62  16500.00   1157.38         7.01
# 123      7898.37   8500.00    601.63         7.08
# 464      9101.88   8500.00   -601.88         7.08
# 701      7888.34   8500.00    611.66         7.20
# 677     49184.75  53000.00   3815.25         7.20
# 601     24128.26  26000.00   1871.74         7.20
# 220     64926.53  70000.00   5073.47         7.25
# 721     64926.53  70000.00   5073.47         7.25
# 487     64926.53  70000.00   5073.47         7.25
# 817     12979.07  14000.00   1020.93         7.29
# 146      8057.37   7500.00   -557.37         7.43
# 320     13435.91  12500.00   -935.91         7.49
# 832     33304.05  36000.00   2695.95         7.49
# 184     24735.19  23000.00  -1735.19         7.54
# 759      7546.78   7000.00   -546.78         7.81
# 355     23036.23  25000.00   1963.77         7.86
# 287      4854.14   4500.00   -354.14         7.87
# 78      11515.79  12500.00    984.21         7.87
# 876     17278.65  16000.00  -1278.65         7.99
# 647     12972.21  12000.00   -972.21         8.10
# 875     32440.09  30000.00  -2440.09         8.13
# 419     10287.99   9500.00   -787.99         8.29
# 479     14078.85  13000.00  -1078.85         8.30
# 706     12836.63  14000.00   1163.37         8.31
# 230     17342.35  16000.00  -1342.35         8.39
# 842      5495.10   6000.00    504.90         8.41
# 498     10302.02   9500.00   -802.02         8.44
# 202      9764.79   9000.00   -764.79         8.50
# 684     14110.55  13000.00  -1110.55         8.54
# 714     20089.20  22000.00   1910.80         8.69
# 916     11870.69  13000.00   1129.31         8.69
# 754     19159.96  21000.00   1840.04         8.76
# 645     22779.12  25000.00   2220.88         8.88
# 569     29153.04  32000.00   2846.96         8.90
# 584     29432.92  27000.00  -2432.92         9.01
# 910      9816.36   9000.00   -816.36         9.07
# 786     18172.90  20000.00   1827.10         9.14
# 339     22709.79  25000.00   2290.21         9.16
# 788      9828.85   9000.00   -828.85         9.21
# 460      7645.22   7000.00   -645.22         9.22
# 364     10893.90  12000.00   1106.10         9.22
# 0       13111.70  12000.00  -1111.70         9.26
# 544      9298.86   8500.00   -798.86         9.40
# 694     49247.71  45000.00  -4247.71         9.44
# 542     49803.71  55000.00   5196.29         9.45
# 265     28951.80  32000.00   3048.20         9.53
# 687     18088.53  20000.00   1911.47         9.56
# 610     67927.84  62000.00  -5927.84         9.56
# 200     39451.52  36000.00  -3451.52         9.59
# 289     36161.58  40000.00   3838.42         9.60
# 261      9039.12  10000.00    960.88         9.61
# 249     11749.05  13000.00   1250.95         9.62
# 44       7677.53   8500.00    822.47         9.68
# 420     10969.09  10000.00   -969.09         9.69
# 254     15342.62  17000.00   1657.38         9.75
# 497     49634.50  55000.00   5365.50         9.76
# 747     14271.20  13000.00  -1271.20         9.78
# 137      9020.90  10000.00    979.10         9.79
# 630      9020.07  10000.00    979.93         9.80
# 484      4943.87   4500.00   -443.87         9.86
# 572     10987.88  10000.00   -987.88         9.88
# 851     11254.62  12500.00   1245.38         9.96
# 338     19775.30  22000.00   2224.70        10.11
# 594      8089.31   9000.00    910.69        10.12
# 326      9875.85  11000.00   1124.15        10.22
# 346     27568.95  25000.00  -2568.95        10.28
# 598      6617.30   6000.00   -617.30        10.29
# 297     11033.54  10000.00  -1033.54        10.34
# 793      7170.51   8000.00    829.49        10.37
# 829     10753.62  12000.00   1246.38        10.39
# 241     14336.12  16000.00   1663.88        10.40
# 107      9855.94  11000.00   1144.06        10.40
# 375      9855.04  11000.00   1144.96        10.41
# 808      9855.04  11000.00   1144.96        10.41
# 395      9854.81  11000.00   1145.19        10.41
# 749     60726.99  55000.00  -5726.99        10.41
# 414     10765.31   9750.00  -1015.31        10.41
# 660     23191.56  21000.00  -2191.56        10.44
# 854      8946.86  10000.00   1053.14        10.53
# 909      8842.89   8000.00   -842.89        10.54
# 792      8842.89   8000.00   -842.89        10.54
# 723     19680.06  22000.00   2319.94        10.55
# 564     14305.90  16000.00   1694.10        10.59
# 52      17874.26  20000.00   2125.74        10.63
# 319     10273.70  11500.00   1226.30        10.66
# 779     22325.29  25000.00   2674.71        10.70
# 131     53543.61  60000.00   6456.39        10.76
# 620     13297.86  12000.00  -1297.86        10.82
# 510     16626.81  15000.00  -1626.81        10.85
# 725     28512.65  32000.00   3487.35        10.90
# 29      66544.20  60000.00  -6544.20        10.91
# 844     62361.45  70000.00   7638.55        10.91
# 522      9353.27  10500.00   1146.73        10.92
# 732     12025.06  13500.00   1474.94        10.93
# 886     12452.52  14000.00   1547.48        11.05
# 229      7557.07   8500.00    942.93        11.09
# 251    115434.60 130000.00  14565.40        11.20
# 59      22189.62  25000.00   2810.38        11.24
# 838     66531.98  75000.00   8468.02        11.29
# 481     13705.13  15500.00   1794.87        11.58
# 809     12836.63  11500.00  -1336.63        11.62
# 830     16777.43  19000.00   2222.57        11.70
# 406     12297.56  11000.00  -1297.56        11.80
# 187     12297.56  11000.00  -1297.56        11.80
# 209      7229.85   8200.00    970.15        11.83
# 796     72704.03  65000.00  -7704.03        11.85
# 207     11017.16  12500.00   1482.84        11.86
# 711      7834.27   7000.00   -834.27        11.92
# 93      17929.00  16000.00  -1929.00        12.06
# 431     11215.12  10000.00  -1215.12        12.15
# 49      14042.72  16000.00   1957.28        12.23
# 124     22459.14  20000.00  -2459.14        12.30
# 267     26306.27  30000.00   3693.73        12.31
# 352     41572.70  37000.00  -4572.70        12.36
# 679     15479.06  17681.00   2201.94        12.45
# 22       4814.30   5500.00    685.70        12.47
# 672     13093.84  15000.00   1906.16        12.71
# 527      9020.07   8000.00  -1020.07        12.75
# 775      9031.76   8000.00  -1031.76        12.90
# 103     16940.02  15000.00  -1940.02        12.93
# 581      6780.30   6000.00   -780.30        13.01
# 234     13031.56  15000.00   1968.44        13.12
# 351      7813.45   9000.00   1186.55        13.18
# 360      9625.30   8500.00  -1125.30        13.24
# 151     18641.71  21500.00   2858.29        13.29
# 444     10767.29   9500.00  -1267.29        13.34
# 43      10767.29   9500.00  -1267.29        13.34
# 794     28347.47  25000.00  -3347.47        13.39
# 507     11254.62  13000.00   1745.38        13.43
# 635     38566.13  34000.00  -4566.13        13.43
# 631      6056.65   7000.00    943.35        13.48
# 106     18160.06  16000.00  -2160.06        13.50
# 612     29519.61  26000.00  -3519.61        13.54
# 774      6916.80   8000.00   1083.20        13.54
# 150     14760.96  13000.00  -1760.96        13.55
# 259     13808.17  16000.00   2191.83        13.70
# 349     56852.53  50000.00  -6852.53        13.71
# 769     13650.09  12000.00  -1650.09        13.75
# 646     12489.42  14500.00   2010.58        13.87
# 690     23239.49  27000.00   3760.51        13.93
# 519      8553.44   7500.00  -1053.44        14.05
# 79      12009.78  14000.00   1990.22        14.22
# 2        9428.32  11000.00   1571.68        14.29
# 782      9145.41   8000.00  -1145.41        14.32
# 506     13705.13  16000.00   2294.87        14.34
# 719     20548.44  24000.00   3451.56        14.38
# 901     21379.66  25000.00   3620.34        14.48
# 232     34381.05  30000.00  -4381.05        14.60
# 140     21336.57  25000.00   3663.43        14.65
# 742     46933.20  55000.00   8066.80        14.67
# 342     21253.16  18500.00  -2753.16        14.88
# 14      23828.96  28000.00   4171.04        14.90
# 309      7229.85   8500.00   1270.15        14.94
# 231     15301.85  18000.00   2698.15        14.99
# 859     28036.40  33000.00   4963.60        15.04
# 102     18665.56  22000.00   3334.44        15.16
# 735     12296.43  14500.00   2203.57        15.20
# 682     76269.99  90000.00  13730.01        15.26
# 534      7495.05   6500.00   -995.05        15.31
# 550      8078.31   7000.00  -1078.31        15.40
# 115     38063.58  45000.00   6936.42        15.41
# 303     76050.90  90000.00  13949.10        15.50
# 905     16897.32  20000.00   3102.68        15.51
# 536      6330.77   7500.00   1169.23        15.59
# 675     10098.72  12000.00   1901.28        15.84
# 423     14305.90  17000.00   2694.10        15.85
# 856     14305.90  17000.00   2694.10        15.85
# 454     35308.63  42000.00   6691.37        15.93
# 871      9274.61   8000.00  -1274.61        15.93
# 504     11753.95  14000.00   2246.05        16.04
# 729     10073.74  12000.00   1926.26        16.05
# 28       7553.76   9000.00   1446.24        16.07
# 27       9299.33   8000.00  -1299.33        16.24
# 531     37204.85  32000.00  -5204.85        16.27
# 461    108555.45 130000.00  21444.55        16.50
# 869     10422.20  12500.00   2077.80        16.62
# 636     40892.59  35000.00  -5892.59        16.84
# 449     14953.97  18000.00   3046.03        16.92
# 428     47948.14  41000.00  -6948.14        16.95
# 801      8188.84   7000.00  -1188.84        16.98
# 409     58500.01  50000.00  -8500.01        17.00
# 72      19919.74  24000.00   4080.26        17.00
# 76      23404.05  20000.00  -3404.05        17.02
# 381     15747.27  18999.00   3251.73        17.12
# 812     22271.87  19000.00  -3271.87        17.22
# 54      40922.90  49500.00   8577.10        17.33
# 697     45467.68  55000.00   9532.32        17.33
# 693     14042.72  17000.00   2957.28        17.40
# 51      14042.72  17000.00   2957.28        17.40
# 638     14042.72  17000.00   2957.28        17.40
# 152      8259.97  10000.00   1740.03        17.40
# 661     21136.57  18000.00  -3136.57        17.43
# 159     64595.63  55000.00  -9595.63        17.45
# 53       7637.78   6500.00  -1137.78        17.50
# 492     21156.59  18000.00  -3156.59        17.54
# 512     11753.95  10000.00  -1753.95        17.54
# 841     90698.35 110000.00  19301.65        17.55
# 800     44669.71  38000.00  -6669.71        17.55
# 915     44669.71  38000.00  -6669.71        17.55
# 465     10301.07  12500.00   2198.93        17.59
# 398      8233.91  10000.00   1766.09        17.66
# 384      4105.12   5000.00    894.88        17.90
# 269     12280.81  15000.00   2719.19        18.13
# 627     12253.27  15000.00   2746.73        18.31
# 467     28562.72  35000.00   6437.28        18.39
# 120     17945.11  22000.00   4054.89        18.43
# 858     10700.47   9000.00  -1700.47        18.89
# 861     81085.72 100000.00  18914.28        18.91
# 757     81085.72 100000.00  18914.28        18.91
# 173      6545.55   5500.00  -1045.55        19.01
# 32      17000.09  21000.00   3999.91        19.05
# 836     24278.96  30000.00   5721.04        19.07
# 154     25883.93  32000.00   6116.07        19.11
# 434      7743.22   6500.00  -1243.22        19.13
# 478     10494.13  13000.00   2505.87        19.28
# 369     10738.68   9000.00  -1738.68        19.32
# 57      47745.14  40000.00  -7745.14        19.36
# 855      8119.77   6800.00  -1319.77        19.41
# 458     10753.62   9000.00  -1753.62        19.48
# 390     10453.60  13000.00   2546.40        19.59
# 505     16751.61  14000.00  -2751.61        19.65
# 524      7229.85   9000.00   1770.15        19.67
# 865     38305.01  32000.00  -6305.01        19.70
# 20      16762.85  14000.00  -2762.85        19.73
# 113     12037.63  15000.00   2962.37        19.75
# 404      9618.12  12000.00   2381.88        19.85
# 33      14382.20  12000.00  -2382.20        19.85
# 13       7191.11   6000.00  -1191.11        19.85
# 323     11989.46  10000.00  -1989.46        19.89
# 4        5995.25   5000.00   -995.25        19.90
# 334     74441.10  62000.00 -12441.10        20.07
# 619      7992.94  10000.00   2007.06        20.07
# 888     11984.47  15000.00   3015.53        20.10
# 837     63915.21  80000.00  16084.79        20.11
# 689      9008.61   7500.00  -1508.61        20.11
# 870      9008.61   7500.00  -1508.61        20.11
# 700      5990.98   7500.00   1509.02        20.12
# 164     17420.03  14500.00  -2920.03        20.14
# 831     17523.15  22000.00   4476.85        20.35
# 494     11135.42  14000.00   2864.58        20.46
# 95       7229.85   6000.00  -1229.85        20.50
# 736     35765.22  45000.00   9234.78        20.52
# 459     14305.90  18000.00   3694.10        20.52
# 810     95335.75 120000.00  24664.25        20.55
# 12      10250.75   8500.00  -1750.75        20.60
# 371     54284.91  45000.00  -9284.91        20.63
# 783     79332.50 100000.00  20667.50        20.67
# 756    110976.63 140000.00  29023.37        20.73
# 19      15832.66  20000.00   4167.34        20.84
# 264     14510.25  12000.00  -2510.25        20.92
# 316     13321.35  11000.00  -2321.35        21.10
# 649     15775.72  20000.00   4224.28        21.12
# 171     20455.81  26000.00   5544.19        21.32
# 578     31468.13  40000.00   8531.87        21.33
# 657      9828.85  12500.00   2671.15        21.37
# 644     85012.97  70000.00 -15012.97        21.45
# 857     18225.80  15000.00  -3225.80        21.51
# 902      7899.10   6500.00  -1399.10        21.52
# 282     11763.99  15000.00   3236.01        21.57
# 766     14098.39  18000.00   3901.61        21.68
# 803     18265.88  15000.00  -3265.88        21.77
# 89      10969.09   9000.00  -1969.09        21.88
# 513     11717.83  15000.00   3282.17        21.88
# 586     21862.14  28000.00   6137.86        21.92
# 313     14042.72  18000.00   3957.28        21.98
# 731     19502.23  25000.00   5497.77        21.99
# 893     15860.72  13000.00  -2860.72        22.01
# 425     17151.85  22000.00   4848.15        22.04
# 477     14009.27  18000.00   3990.73        22.17
# 9        9775.05   8000.00  -1775.05        22.19
# 306     74579.21  61000.00 -13579.21        22.26
# 761     13987.62  18000.00   4012.38        22.29
# 328     24861.32  32000.00   7138.68        22.31
# 31      55051.37  45000.00 -10051.37        22.34
# 387     18633.58  24000.00   5366.42        22.36
# 25      41659.95  34000.00  -7659.95        22.53
# 299     50225.26  65000.00  14774.74        22.73
# 567     12280.81  10000.00  -2280.81        22.81
# 179     27015.83  35000.00   7984.17        22.81
# 591     27013.13  35000.00   7986.87        22.82
# 38      27029.82  22000.00  -5029.82        22.86
# 432      7991.24   6500.00  -1491.24        22.94
# 877     38499.53  50000.00  11500.47        23.00
# 493      6916.80   9000.00   2083.20        23.15
# 516     12296.43  16000.00   3703.57        23.15
# 695      9855.04   8000.00  -1855.04        23.19
# 331     10753.62  14000.00   3246.38        23.19
# 579     15342.62  20000.00   4657.38        23.29
# 221     39499.09  32000.00  -7499.09        23.43
# 890     11481.18  15000.00   3518.82        23.46
# 914      8046.79   6500.00  -1546.79        23.80
# 75      21336.57  28000.00   6663.43        23.80
# 285     60951.39  80000.00  19048.61        23.81
# 853     41889.31  55000.00  13110.69        23.84
# 136     55735.75  45000.00 -10735.75        23.86
# 21      16748.53  22000.00   5251.47        23.87
# 180     68134.09  55000.00 -13134.09        23.88
# 212     16744.64  13500.00  -3244.64        24.03
# 347      9855.04  13000.00   3144.96        24.19
# 722     45467.68  60000.00  14532.32        24.22
# 903      8074.39   6500.00  -1574.39        24.22
# 790     18176.65  24000.00   5823.35        24.26
# 133     18657.79  15000.00  -3657.79        24.39
# 583     37772.64  50000.00  12227.36        24.45
# 359     49782.57  40000.00  -9782.57        24.46
# 847     56024.33  45000.00 -11024.33        24.50
# 36       9429.18  12500.00   3070.82        24.57
# 388     49828.62  40000.00  -9828.62        24.57
# 263      7475.13   6000.00  -1475.13        24.59
# 235     63710.03  84500.00  20789.97        24.60
# 147     46691.44  62000.00  15308.56        24.69
# 127     11229.86   9000.00  -2229.86        24.78
# 573     14973.78  12000.00  -2973.78        24.78
# 626      9020.07  12000.00   2979.93        24.83
# 365     10518.16  14000.00   3481.84        24.87
# 46      17491.13  14000.00  -3491.13        24.94
# 63      11254.62  15000.00   3745.38        24.97
# 134     33705.69  45000.00  11294.31        25.10
# 379     14973.78  20000.00   5026.22        25.13
# 811     74771.79 100000.00  25228.21        25.23
# 310     15041.24  12000.00  -3041.24        25.34
# 743     15041.24  12000.00  -3041.24        25.34
# 167     15041.24  12000.00  -3041.24        25.34
# 641     43885.75  35000.00  -8885.75        25.39
# 248     11920.00  16000.00   4080.00        25.50
# 639     26034.75  35000.00   8965.25        25.62
# 740    141227.92 190000.00  48772.08        25.67
# 128     55745.99  75000.00  19254.01        25.67
# 122      9428.32   7500.00  -1928.32        25.71
# 705     17084.12  23000.00   5915.88        25.72
# 772     20009.88  26969.00   6959.12        25.80
# 744      9638.43  13000.00   3361.57        25.86
# 789      7384.66  10000.00   2615.34        26.15
# 272     12543.97  17000.00   4456.03        26.21
# 176     10098.72   8000.00  -2098.72        26.23
# 105      8842.89   7000.00  -1842.89        26.33
# 683      8842.89   7000.00  -1842.89        26.33
# 23      37898.95  30000.00  -7898.95        26.33
# 412     18395.80  25000.00   6604.20        26.42
# 608     24027.54  19000.00  -5027.54        26.46
# 717    132350.80 180000.00  47649.20        26.47
# 776     11017.16  15000.00   3982.84        26.55
# 710     14678.29  20000.00   5321.71        26.61
# 566      6330.77   5000.00  -1330.77        26.62
# 553     22790.88  18000.00  -4790.88        26.62
# 188     10255.89  14000.00   3744.11        26.74
# 311     34250.61  27000.00  -7250.61        26.85
# 480     10969.09  15000.00   4030.91        26.87
# 393      9855.04  13500.00   3644.96        27.00
# 39      27628.81  38000.00  10371.19        27.29
# 521     19094.34  15000.00  -4094.34        27.30
# 558      9559.33   7500.00  -2059.33        27.46
# 284     25493.10  20000.00  -5493.10        27.47
# 66      52290.30  41000.00 -11290.30        27.54
# 34      14042.72  11000.00  -3042.72        27.66
# 739      7229.85  10000.00   2770.15        27.70
# 250     10111.44  14000.00   3888.56        27.78
# 537     38371.19  30000.00  -8371.19        27.90
# 596     32424.18  45000.00  12575.82        27.95
# 611     32317.01  45000.00  12682.99        28.18
# 189     10767.29  15000.00   4232.71        28.22
# 715     10767.29  15000.00   4232.71        28.22
# 340     64582.57  90000.00  25417.43        28.24
# 350      7697.99   6000.00  -1697.99        28.30
# 463     10274.64   8000.00  -2274.64        28.43
# 74      14311.86  20000.00   5688.14        28.44
# 501     12836.63  18000.00   5163.37        28.69
# 430      9605.01  13500.00   3894.99        28.85
# 503     24893.61  35000.00  10106.39        28.88
# 658    180591.40 140000.00 -40591.40        28.99
# 67      21279.86  30000.00   8720.14        29.07
# 156     17458.15  13500.00  -3958.15        29.32
# 540     41623.09  59000.00  17376.91        29.45
# 377     16829.30  13000.00  -3829.30        29.46
# 35       9842.52   7600.00  -2242.52        29.51
# 629     29516.62  42000.00  12483.38        29.72
# 405     11686.28   9000.00  -2686.28        29.85
# 849     10516.29  15000.00   4483.71        29.89
# 561     13004.09  10000.00  -3004.09        30.04
# 768     16762.85  24000.00   7237.15        30.15
# 738     13686.46  10500.00  -3186.46        30.35
# 260     54751.94  42000.00 -12751.94        30.36
# 827     37921.36  54500.00  16578.64        30.42
# 165     22198.86  17000.00  -5198.86        30.58
# 678     39198.28  30000.00  -9198.28        30.66
# 835     13099.29  10000.00  -3099.29        30.99
# 795      9828.85   7500.00  -2328.85        31.05
# 239      7556.37  11000.00   3443.63        31.31
# 6        8234.71  12000.00   3765.29        31.38
# 673      7888.34   6000.00  -1888.34        31.47
# 462      8559.47  12500.00   3940.53        31.52
# 852     64926.53  95000.00  30073.47        31.66
# 764     13668.71  20000.00   6331.29        31.66
# 203     12297.56  18000.00   5702.44        31.68
# 204     12296.43  18000.00   5703.57        31.69
# 637     18428.10  27000.00   8571.90        31.75
# 907      8188.84  12000.00   3811.16        31.76
# 244     15686.23  23000.00   7313.77        31.80
# 908     20457.69  30000.00   9542.31        31.81
# 348     20431.58  15500.00  -4931.58        31.82
# 145      9233.07   7000.00  -2233.07        31.90
# 709     25843.92  38000.00  12156.08        31.99
# 850     20358.45  30000.00   9641.55        32.14
# 410     18981.98  28000.00   9018.02        32.21
# 656     33182.94  49000.00  15817.06        32.28
# 664      7546.78   5700.00  -1846.78        32.40
# 815     10098.72  15000.00   4901.28        32.68
# 42      19921.86  15000.00  -4921.86        32.81
# 797     18596.63  14000.00  -4596.63        32.83
# 471     10060.94  15000.00   4939.06        32.93
# 570     86956.39 130000.00  43043.61        33.11
# 41      21391.97  32000.00  10608.03        33.15
# 523     11027.59  16500.00   5472.41        33.17
# 535     48050.51  72000.00  23949.49        33.26
# 18      18338.28  27500.00   9161.72        33.32
# 469     12000.00   9000.00  -3000.00        33.33
# 770      6676.70   5000.00  -1676.70        33.53
# 330     19935.98  30000.00  10064.02        33.55
# 211     49562.70  75000.00  25437.30        33.92
# 357     53568.80  40000.00 -13568.80        33.92
# 84      52706.54  80000.00  27293.46        34.12
# 125     20403.32  31000.00  10596.68        34.18
# 191     26844.13  20000.00  -6844.13        34.22
# 181      8057.37   6000.00  -2057.37        34.29
# 456     16424.72  25000.00   8575.28        34.30
# 208      9403.26   7000.00  -2403.26        34.33
# 321     13435.91  10000.00  -3435.91        34.36
# 144      9842.52  15000.00   5157.48        34.38
# 599     11810.63  18000.00   6189.37        34.39
# 257     36292.28  27000.00  -9292.28        34.42
# 168     10753.62   8000.00  -2753.62        34.42
# 895     13093.84  20000.00   6906.16        34.53
# 439     13093.84  20000.00   6906.16        34.53
# 17      85012.97 130000.00  44987.03        34.61
# 652     32664.47  50000.00  17335.53        34.67
# 822      9428.32   7000.00  -2428.32        34.69
# 483     26944.03  20000.00  -6944.03        34.72
# 290      7409.98   5500.00  -1909.98        34.73
# 143     48934.72  75000.00  26065.28        34.75
# 278     13024.47  20000.00   6975.53        34.88
# 291     52035.71  80000.00  27964.29        34.96
# 565      9749.08  15000.00   5250.92        35.01
# 345     12836.63   9500.00  -3336.63        35.12
# 741     27029.82  20000.00  -7029.82        35.15
# 380     29120.50  45000.00  15879.50        35.29
# 676     40593.79  30000.00 -10593.79        35.31
# 353      9020.07  14000.00   4979.93        35.57
# 155      6780.30   5000.00  -1780.30        35.61
# 195     18657.79  29000.00  10342.21        35.66
# 62      15729.68  24500.00   8770.32        35.80
# 121     10233.02  16000.00   5766.98        36.04
# 712     16586.10  26000.00   9413.90        36.21
# 602     20393.38  32000.00  11606.62        36.27
# 615     40885.08  30000.00 -10885.08        36.28
# 366     10908.02   8000.00  -2908.02        36.35
# 543     68197.11  50000.00 -18197.11        36.39
# 295     57224.22  90000.00  32775.78        36.42
# 807      8188.84   6000.00  -2188.84        36.48
# 592      8188.84   6000.00  -2188.84        36.48
# 158     28537.23  45000.00  16462.77        36.58
# 530     47815.79  34999.00 -12816.79        36.62
# 863     12297.56   9000.00  -3297.56        36.64
# 407     10767.29  17000.00   6232.71        36.66
# 668     88591.63 140000.00  51408.37        36.72
# 526     10939.94   8000.00  -2939.94        36.75
# 833     88509.76 140000.00  51490.24        36.78
# 98      57461.31  42000.00 -15461.31        36.81
# 520     13686.46  10000.00  -3686.46        36.86
# 917     69445.30 110000.00  40554.70        36.87
# 597     34250.61  25000.00  -9250.61        37.00
# 633     50385.18  80000.00  29614.82        37.02
# 621     11240.32   8200.00  -3040.32        37.08
# 839     47153.31  75000.00  27846.69        37.13
# 760      9429.18  15000.00   5570.82        37.14
# 11      10292.27   7500.00  -2792.27        37.23
# 356     12526.88  20000.00   7473.12        37.37
# 161     15651.49  25000.00   9348.51        37.39
# 199     62534.06 100000.00  37465.94        37.47
# 227     13748.04  22000.00   8251.96        37.51
# 447     24987.11  40000.00  15012.89        37.53
# 574      6244.39  10000.00   3755.61        37.56
# 82      11532.91  18500.00   6967.09        37.66
# 616      9647.11   7000.00  -2647.11        37.82
# 864     23447.74  17000.00  -6447.74        37.93
# 307     22271.87  36000.00  13728.13        38.13
# 301     11749.05   8500.00  -3249.05        38.22
# 502     11749.05   8500.00  -3249.05        38.22
# 669     15213.21  11000.00  -4213.21        38.30
# 897    104859.46 170000.00  65140.54        38.32
# 824     92515.67 150000.00  57484.33        38.32
# 791     12943.19  21000.00   8056.81        38.37
# 607     12263.75  20000.00   7736.25        38.68
# 557     11094.62   8000.00  -3094.62        38.68
# 222      8578.90  14000.00   5421.10        38.72
# 490      7339.03  12000.00   4660.97        38.84
# 373     39707.11  65000.00  25292.89        38.91
# 745     39707.11  65000.00  25292.89        38.91
# 896      5143.86   3700.00  -1443.86        39.02
# 892     22281.54  16000.00  -6281.54        39.26
# 416     24269.55  40000.00  15730.45        39.33
# 129     21226.66  35000.00  13773.34        39.35
# 217     22302.25  16000.00  -6302.25        39.39
# 197     15342.62  11000.00  -4342.62        39.48
# 750     30246.48  50000.00  19753.52        39.51
# 708     39317.29  65000.00  25682.71        39.51
# 215     12571.61   9000.00  -3571.61        39.68
# 26      17479.79  12500.00  -4979.79        39.84
# 818      9007.61  15000.00   5992.39        39.95
# 879     15012.66  25000.00   9987.34        39.95
# 305     51013.55  85000.00  33986.45        39.98
# 589     10508.44   7500.00  -3008.44        40.11
# 665     10508.44   7500.00  -3008.44        40.11
# 820     14019.65  10000.00  -4019.65        40.20
# 737      8370.57  14000.00   5629.43        40.21
# 60       9816.36   7000.00  -2816.36        40.23
# 727     42080.86  30000.00 -12080.86        40.27
# 613     18250.27  13000.00  -5250.27        40.39
# 236     35103.98  25000.00 -10103.98        40.42
# 681     50573.21  36000.00 -14573.21        40.48
# 333      9842.52   7000.00  -2842.52        40.61
# 317      9855.04   7000.00  -2855.04        40.79
# 453      7045.78   5000.00  -2045.78        40.92
# 554     88509.76 150000.00  61490.24        40.99
# 688     88509.76 150000.00  61490.24        40.99
# 315      5874.38  10000.00   4125.62        41.26
# 724     58269.03 100000.00  41730.97        41.73
# 563      8509.88   6000.00  -2509.88        41.83
# 867     13358.66  23000.00   9641.34        41.92
# 595     86956.39 150000.00  63043.61        42.03
# 110      7813.45   5500.00  -2313.45        42.06
# 891      9970.92   7000.00  -2970.92        42.44
# 198    103598.05 180000.00  76401.95        42.45
# 118      8618.54  15000.00   6381.46        42.54
# 293     48813.64  85000.00  36186.36        42.57
# 720      6866.38  12000.00   5133.62        42.78
# 7        5716.91  10000.00   4283.09        42.83
# 798     64280.79  45000.00 -19280.79        42.85
# 24      17151.85  12000.00  -5151.85        42.93
# 470      6721.03   4700.00  -2021.03        43.00
# 533      9297.62   6500.00  -2797.62        43.04
# 784      7152.77   5000.00  -2152.77        43.06
# 662      5731.57   4000.00  -1731.57        43.29
# 5        5383.89   9500.00   4116.11        43.33
# 457      8618.54   6000.00  -2618.54        43.64
# 292     25859.44  18000.00  -7859.44        43.66
# 341     11255.65  20000.00   8744.35        43.72
# 899      6749.89  12000.00   5250.11        43.75
# 142     43155.42  30000.00 -13155.42        43.85
# 71      14024.89  25000.00  10975.11        43.90
# 804     16762.85  30000.00  13237.15        44.12
# 828      7220.00   5000.00  -2220.00        44.40
# 773     10555.79  19000.00   8444.21        44.44
# 491     21701.70  15000.00  -6701.70        44.68
# 97       8252.99  15000.00   6747.01        44.98
# 214     19224.64  35000.00  15775.36        45.07
# 86      13059.04   9000.00  -4059.04        45.10
# 834     13668.71  25000.00  11331.29        45.33
# 787      8193.55  15000.00   6806.45        45.38
# 219     12543.97  23000.00  10456.03        45.46
# 846     37834.47  26000.00 -11834.47        45.52
# 755     40789.54  75000.00  34210.46        45.61
# 753     11920.00  22000.00  10080.00        45.82
# 275     18965.76  13000.00  -5965.76        45.89
# 94      11902.32  22000.00  10097.68        45.90
# 117    145888.04 270000.00 124111.96        45.97
# 547     81010.79 150000.00  68989.21        45.99
# 667     81010.79 150000.00  68989.21        45.99
# 443     13145.74   9000.00  -4145.74        46.06
# 576     15342.62  10500.00  -4842.62        46.12
# 372     10679.91  20000.00   9320.09        46.60
# 50      17054.86  32000.00  14945.14        46.70
# 233     11717.83  22000.00  10282.17        46.74
# 436     10278.88   7000.00  -3278.88        46.84
# 247     11013.26   7500.00  -3513.26        46.84
# 632      8229.90  15500.00   7270.10        46.90
# 245     30852.52  21000.00  -9852.52        46.92
# 172     11135.65  21000.00   9864.35        46.97
# 659     11637.51  22000.00  10362.49        47.10
# 528     10302.02   7000.00  -3302.02        47.17
# 571     22085.32  15000.00  -7085.32        47.24
# 805     18422.55  35000.00  16577.45        47.36
# 437      8842.89   6000.00  -2842.89        47.38
# 153      8842.89   6000.00  -2842.89        47.38
# 485     16748.53  32000.00  15251.47        47.66
# 593     52035.71 100000.00  47964.29        47.96
# 77       9353.27  18000.00   8646.73        48.04
# 913     18508.11  12500.00  -6008.11        48.06
# 883     44446.90  30000.00 -14446.90        48.16
# 210     20721.38  40000.00  19278.62        48.20
# 603     23727.21  16000.00  -7727.21        48.30
# 402     10287.99  20000.00   9712.01        48.56
# 781     12852.96  25000.00  12147.04        48.59
# 605     17961.29  35000.00  17038.71        48.68
# 548     19476.93  38000.00  18523.07        48.74
# 69      12810.20  25000.00  12189.80        48.76
# 651     13400.21   9000.00  -4400.21        48.89
# 318     11220.82  22000.00  10779.18        49.00
# 258      5604.74  11000.00   5395.26        49.05
# 588      5073.83  10000.00   4926.17        49.26
# 370      8339.92  16500.00   8160.08        49.46
# 55      14199.15   9500.00  -4699.15        49.46
# 99      10466.24   7000.00  -3466.24        49.52
# 268     47854.78  95000.00  47145.22        49.63
# 185     18165.91  36125.00  17959.09        49.71
# 70      12726.52   8500.00  -4226.52        49.72
# 100     14973.78  10000.00  -4973.78        49.74
# 322     12543.97  25000.00  12456.03        49.82
# 600      8990.07   6000.00  -2990.07        49.83
# 109     92246.56  61500.00 -30746.56        49.99
# 415     12956.06  26000.00  13043.94        50.17
# 730     60074.53  40000.00 -20074.53        50.19
# 771      6959.12  14000.00   7040.88        50.29
# 218     10530.64   7000.00  -3530.64        50.44
# 213      9846.62  20000.00  10153.38        50.77
# 482      7384.66  15000.00   7615.34        50.77
# 666      6305.35  13000.00   6694.65        51.50
# 728     17455.98  11500.00  -5955.98        51.79
# 843     13686.46   9000.00  -4686.46        52.07
# 698      9886.81   6500.00  -3386.81        52.10
# 878     18270.91  12000.00  -6270.91        52.26
# 64      16762.85  11000.00  -5762.85        52.39
# 823      7624.91   5000.00  -2624.91        52.50
# 904      7624.91   5000.00  -2624.91        52.50
# 426     19827.79  13000.00  -6827.79        52.52
# 654     19827.79  13000.00  -6827.79        52.52
# 778     30773.97  65000.00  34226.03        52.66
# 177    132350.80 280000.00 147649.20        52.73
# 73       5365.34   3500.00  -1865.34        53.30
# 368      8339.92  18000.00   9660.08        53.67
# 825      9239.08   6000.00  -3239.08        53.98
# 806     46007.99 100000.00  53992.01        53.99
# 262     77810.27 170000.00  92189.73        54.23
# 270     16424.72  36000.00  19575.28        54.38
# 816     45419.46 100000.00  54580.54        54.58
# 777     81407.15 180000.00  98592.85        54.77
# 96      36086.26  80000.00  43913.74        54.89
# 175      4646.80   3000.00  -1646.80        54.89
# 614     41903.75  27000.00 -14903.75        55.20
# 237      5822.22  13000.00   7177.78        55.21
# 196      5784.35  13000.00   7215.65        55.51
# 496     53261.52 120000.00  66738.48        55.62
# 622     61654.52 140000.00  78345.48        55.96
# 298     78017.60  50000.00 -28017.60        56.04
# 166     10969.09  25000.00  14030.91        56.12
# 8       73552.15  47000.00 -26552.15        56.49
# 634     28238.55  65000.00  36761.45        56.56
# 562      5210.39  12000.00   6789.61        56.58
# 814     11749.05   7500.00  -4249.05        56.65
# 141     86652.40 200000.00 113347.60        56.67
# 401     64926.53 150000.00  85073.47        56.72
# 906     15686.26  10000.00  -5686.26        56.86
# 518     10996.84   7000.00  -3996.84        57.10
# 556     20455.81  13000.00  -7455.81        57.35
# 343      7645.22  18000.00  10354.78        57.53
# 302     22085.32  14000.00  -8085.32        57.75
# 114     40237.92  25500.00 -14737.92        57.80
# 392      9776.60   6166.00  -3610.60        58.56
# 88      19071.83  12000.00  -7071.83        58.93
# 511     14311.86   9000.00  -5311.86        59.02
# 799      8188.84   5146.00  -3042.84        59.13
# 65       9557.65   6000.00  -3557.65        59.29
# 178     19145.22  12000.00  -7145.22        59.54
# 1       15200.21   9500.00  -5700.21        60.00
# 40      51225.18  32000.00 -19225.18        60.08
# 514     12009.78   7500.00  -4509.78        60.13
# 255      5608.17   3500.00  -2108.17        60.23
# 509     12852.96   8000.00  -4852.96        60.66
# 604     12854.14   8000.00  -4854.14        60.68
# 396     13668.71   8500.00  -5168.71        60.81
# 424      9173.18   5700.00  -3473.18        60.93
# 802      9661.45   6000.00  -3661.45        61.02
# 386     23311.64  60000.00  36688.36        61.15
# 699     32290.69  20000.00 -12290.69        61.45
# 568     29086.64  18000.00 -11086.64        61.59
# 418     24274.49  15000.00  -9274.49        61.83
# 190     15218.10  40000.00  24781.90        61.95
# 713      6486.72   4000.00  -2486.72        62.17
# 87       9758.78   6000.00  -3758.78        62.65
# 532     66544.20 180000.00 113455.80        63.03
# 246      7384.66  20000.00  12615.34        63.08
# 692     19570.08  12000.00  -7570.08        63.08
# 488     13050.92   8000.00  -5050.92        63.14
# 718      8794.89  24000.00  15205.11        63.35
# 112     12818.80  35000.00  22181.20        63.37
# 266     45745.38  28000.00 -17745.38        63.38
# 394     40892.59  25000.00 -15892.59        63.57
# 704     36872.58  22500.00 -14372.58        63.88
# 242     33129.14  20000.00 -13129.14        65.65
# 845     68582.89 200000.00 131417.11        65.71
# 238     11997.47  35000.00  23002.53        65.72
# 577     12493.59   7500.00  -4993.59        66.58
# 517     35017.12  21000.00 -14017.12        66.75
# 90      20009.88  12000.00  -8009.88        66.75
# 367     16702.30  10000.00  -6702.30        67.02
# 361     40089.32  24000.00 -16089.32        67.04
# 182     14544.72  44300.00  29755.28        67.17
# 545      5528.77  17000.00  11471.23        67.48
# 223     16762.85  10000.00  -6762.85        67.63
# 135     14544.72  45000.00  30455.28        67.68
# 575     11749.05   7000.00  -4749.05        67.84
# 335     12182.29  38000.00  25817.71        67.94
# 170     13435.91   8000.00  -5435.91        67.95
# 376     13435.91   8000.00  -5435.91        67.95
# 819      5753.51  18000.00  12246.49        68.04
# 391     24460.08  14500.00  -9960.08        68.69
# 274     38852.79  23000.00 -15852.79        68.93
# 312     27922.19  16500.00 -11422.19        69.23
# 411     11012.57   6500.00  -4512.57        69.42
# 304      7523.23  25000.00  17476.77        69.91
# 224      8889.77  30000.00  21110.23        70.37
# 508     42806.63  25000.00 -17806.63        71.23
# 413     10043.92  35000.00  24956.08        71.30
# 623     20580.70  12000.00  -8580.70        71.51
# 680     10301.07   6000.00  -4301.07        71.68
# 45       8093.67   4700.00  -3393.67        72.21
# 821     34446.63  20000.00 -14446.63        72.23
# 271      7483.37  27000.00  19516.63        72.28
# 655      7683.06  30000.00  22316.94        74.39
# 862      5765.76  23000.00  17234.24        74.93
# 475     36094.61  20500.00 -15594.61        76.07
# 183      7079.48   4000.00  -3079.48        76.99
# 16       8390.94  37000.00  28609.06        77.32
# 403     79830.68  45000.00 -34830.68        77.40
# 912      8871.40   5000.00  -3871.40        77.43
# 126     21364.22  12000.00  -9364.22        78.04
# 889     92656.27  52000.00 -40656.27        78.19
# 525     54217.38 250000.00 195782.62        78.31
# 628     10758.10   6000.00  -4758.10        79.30
# 873     13192.66  65000.00  51807.34        79.70
# 474     17077.01   9500.00  -7577.01        79.76
# 455      8431.85  45000.00  36568.15        81.26
# 767     49296.53  27000.00 -22296.53        82.58
# 539     10969.09   6000.00  -4969.09        82.82
# 826     14578.12  85000.00  70421.88        82.85
# 226     11917.74   6500.00  -5417.74        83.35
# 83      15200.21 100000.00  84799.79        84.80
# 81      12036.99   6500.00  -5536.99        85.18
# 582     17706.71   9500.00  -8206.71        86.39
# 499     59661.21  32000.00 -27661.21        86.44
# 10      15940.83   8500.00  -7440.83        87.54
# 327     13248.45   7000.00  -6248.45        89.26
# 446     19002.96  10000.00  -9002.96        90.03
# 130     14228.95 150000.00 135771.05        90.51
# 111      9012.37 100000.00  90987.63        90.99
# 643     76515.38  40000.00 -36515.38        91.29
# 468     28859.91  15000.00 -13859.91        92.40
# 606     29991.34  15500.00 -14491.34        93.49
# 132     16468.19   8500.00  -7968.19        93.74
# 324     13746.44   7000.00  -6746.44        96.38
# 691     14024.89   7000.00  -7024.89       100.36
# 385     33063.44  16500.00 -16563.44       100.38
# 358     40204.69  20000.00 -20204.69       101.02
# 160     15342.62   7500.00  -7842.62       104.57
# 707     15344.04   7500.00  -7844.04       104.59
# 648     26084.87  12500.00 -13584.87       108.68
# 421     17791.40   8500.00  -9291.40       109.31
# 451     31643.26  15000.00 -16643.26       110.96
# 452     21156.59  10000.00 -11156.59       111.57
# 119     44806.49  21000.00 -23806.49       113.36
# 37      60525.47  28000.00 -32525.47       116.16
# 101     30308.99  14000.00 -16308.99       116.49
# 332     12304.11   5500.00  -6804.11       123.71
# 104     31487.81  14000.00 -17487.81       124.91
# 609     27498.43  12000.00 -15498.43       129.15
# 486     19640.74   8500.00 -11140.74       131.07
# 555     17378.53   7500.00  -9878.53       131.71
# 495      6997.48   3000.00  -3997.48       133.25
# 399     11717.83   5000.00  -6717.83       134.36
# 670     11717.83   5000.00  -6717.83       134.36
# 91      12253.27   5000.00  -7253.27       145.07
# 552     38064.35  15000.00 -23064.35       153.76
# 225     33089.52  13000.00 -20089.52       154.53
# 880     36648.87  14000.00 -22648.87       161.78
# 763      9420.26   3500.00  -5920.26       169.15
# 157     36327.08  13000.00 -23327.08       179.44
# 422     28233.37  10000.00 -18233.37       182.33
# 162     10893.90   3500.00  -7393.90       211.25
# 354     28238.55   8500.00 -19738.55       232.22
# 288     36974.76  11000.00 -25974.76       236.13
# 874      7495.05   2200.00  -5295.05       240.68
# 473      7287.24   2000.00  -5287.24       264.36
# 866     30043.89   8000.00 -22043.89       275.55
# 281     27015.83   6000.00 -21015.83       350.26
# 696     37307.40   8000.00 -29307.40       366.34
